# %% [markdown]
# *Note: This manuscript is not meant to be an explanation of all Fundamental Analysis. It just shows some codes that you may use to explore YFinance stocks.
#
# For more detailed description, check with bard.google.com

# %% [markdown]
# ---

# %% [markdown]
# #Install and Import YFinance

# %%
# !pip install --upgrade yfinance
import yfinance as yf

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Info

# %%
stock = yf.Ticker("D05.SI")

# %%
import pandas as pd

info = stock.info

df1 = pd.DataFrame(info.items(), columns=["Key", "Value"])

display(df1)
# Out:
#                    Key                        Value
# 0             address1  Marina Bay Financial Centre
# 1             address2  Tower 3 12 Marina Boulevard
# 2                 city                    Singapore
# 3                  zip                       018982
# 4              country                    Singapore
# ..                 ...                          ...
# 111       grossMargins                          0.0
# 112      ebitdaMargins                          0.0
# 113   operatingMargins                      0.58947
# 114  financialCurrency                          SGD
# 115   trailingPegRatio                       1.5165
#
# [116 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Actions (Dividends and Splits)

# %%
# get historical market data
hist = stock.history(period="max")

# show actions (dividends, splits)
display(stock.actions)
# Out:
#                            Dividends  Stock Splits
# Date
# 2000-05-17 00:00:00+08:00       0.16           0.0
# 2000-08-08 00:00:00+08:00       0.14           0.0
# 2001-05-16 00:00:00+08:00       0.15           0.0
# 2001-08-02 00:00:00+08:00       0.14           0.0
# 2002-05-03 00:00:00+08:00       0.16           0.0
# ...                              ...           ...
# 2022-05-11 00:00:00+08:00       0.36           0.0
# 2022-08-15 00:00:00+08:00       0.36           0.0
# 2022-11-11 00:00:00+08:00       0.36           0.0
# 2023-04-10 00:00:00+08:00       0.50           0.0
# 2023-05-09 00:00:00+08:00       0.42           0.0
#
# [66 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Financials

# %%
# show financials
display(stock.financials)
# Out:
#                                                            2022-12-31  \
# Tax Effect Of Unusual Items                             379876.358985
# Tax Rate For Calcs                                           0.126625
# Total Unusual Items                                         3000000.0
# Total Unusual Items Excluding Goodwill                      3000000.0
# Net Income From Continuing Operation Net Minori...       8193000000.0
# Reconciled Depreciation                                   701000000.0
# Net Interest Income                                     10941000000.0
# Interest Expense                                         4986000000.0
# Interest Income                                         15927000000.0
# Normalized Income                                   8190379876.358985
# Net Income From Continuing And Discontinued Ope...       8193000000.0
# Diluted Average Shares                                   2572833000.0
# ...

# %% [markdown]
# ## Stock.Quarterly Financials

# %%
#show quarterly financials
display(stock.quarterly_financials)
# Out:
#                                                       2023-06-30  \
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                           0.4
# Net Income From Continuing Operation Net Minori...  2629000000.0
# Net Interest Income                                 3433000000.0
# Interest Income                                     9957000000.0
# Normalized Income                                   2629000000.0
# Net Income From Continuing And Discontinued Ope...  2629000000.0
# Diluted Average Shares                                       NaN
# Basic Average Shares                                         NaN
# Diluted EPS                                                  NaN
# Basic EPS                                                    NaN
# Diluted NI Availto Com Stockholders                 2629000000.0
# Net Income Common Stockholders                      2629000000.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Major Holders

# %%
# show major holders
display(stock.major_holders)
# Out:
#         0                                      1
# 0   0.96%        % of Shares Held by All Insider
# 1  55.94%       % of Shares Held by Institutions
# 2  56.49%        % of Float Held by Institutions
# 3     558  Number of Institutions Holding Shares

# %% [markdown]
# ##Stock.Institutional Holders

# %%
# show institutional holders
display(stock.institutional_holders)
# Out:
#                                    Holder   Shares Date Reported   % Out  \
# 0       Aristotle Capital Management, LLC  2953172    2023-03-31  0.0011
# 1  Paradigm Asset Management Company, LLC   102400    2023-03-31  0.0000
# 2                    Pacer Advisors, Inc.    15030    2023-06-30  0.0000
#
#        Value
# 0  101293797
# 1    3512319
# 2     515528

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Balance Sheet

# %%
# show balance sheet
display(stock.balance_sheet)
# Out:
#                                                  2022-12-31      2021-12-31  \
# Treasury Shares Number                           15454520.0      20873000.0
# Ordinary Shares Number                         2572163480.0    2566745000.0
# Share Issued                                   2587618000.0    2587618000.0
# Total Debt                                    47079000000.0   53863000000.0
# Tangible Book Value                           51547000000.0   52164000000.0
# Invested Capital                             102577000000.0  109867000000.0
# Net Tangible Assets                           51547000000.0   52164000000.0
# Common Stock Equity                           56887000000.0   57526000000.0
# Total Capitalization                         102577000000.0  109867000000.0
# Total Equity Gross Minority Interest          57072000000.0   57714000000.0
# Minority Interest                               185000000.0     188000000.0
# ...

# %% [markdown]
# ##Stock.Quarterly Balance Sheet

# %%
display(stock.quarterly_balance_sheet)
# Out:
#                                                  2023-06-30      2023-03-31  \
# Treasury Shares Number                            8597816.0       8783220.0
# Ordinary Shares Number                         2579019809.0    2578834405.0
# Share Issued                                   2587617625.0    2587617625.0
# Total Debt                                    49671000000.0             NaN
# Tangible Book Value                           53404000000.0   57595000000.0
# Invested Capital                             108419000000.0             NaN
# Net Tangible Assets                           53404000000.0   57595000000.0
# Common Stock Equity                           58748000000.0   57595000000.0
# Total Capitalization                         108419000000.0             NaN
# Total Equity Gross Minority Interest          58935000000.0             NaN
# Minority Interest                               187000000.0             NaN
# ...

# %% [markdown]
# ---

# %% [markdown]
# #Stock.Cashflow

# %%
# show cashflow
display(stock.cashflow)
# Out:
#                                           2022-12-31     2021-12-31  \
# Free Cash Flow                          2100000000.0   7164000000.0
# Repurchase Of Capital Stock              -11000000.0    -16000000.0
# Repayment Of Debt                                0.0   -257000000.0
# Issuance Of Debt                                 0.0   1000000000.0
# Capital Expenditure                     -669000000.0   -567000000.0
# End Cash Position                      43976000000.0  46690000000.0
# Beginning Cash Position                46690000000.0  42202000000.0
# Effect Of Exchange Rate Changes         -903000000.0    940000000.0
# Changes In Cash                        -1811000000.0   3548000000.0
# Financing Cash Flow                    -3886000000.0  -2582000000.0
# Net Other Financing Charges                      NaN   -853000000.0
# Interest Paid Cff                        -86000000.0    -64000000.0
# Cash Dividends Paid                    -3789000000.0  -2392000000.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# #THE END

# %% [markdown]
# ---
